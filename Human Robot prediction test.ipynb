# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import os
import h5py
loaded_model = load_model('model.h5')
img_path = './test images/Bryan_Dechart_QD_interview_(cropped).jpg'


img = image.load_img(img_path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x /= 255


# Make the prediction
prediction = loaded_model.predict(x)
plt.imshow(x[0])
if prediction < 0.5:
    print("There is a",(1.0-prediction),"% that this image is of a human.")
  
    
else:
   print("There is a",(prediction),"% that this image is of a robot.")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# There is a [[0.9479036]] % that this image is of a human.

# %%
img_path2 = './test images/s-l1200.webp'
img2 = image.load_img(img_path2, target_size=(150, 150))
y = image.img_to_array(img2)
y = np.expand_dims(y, axis=0)
y /= 255
prediction = loaded_model.predict(y)
plt.imshow(y[0])
if prediction < 0.5:
    print("There is a",(1.0-prediction),"% that this image is of a human.")
  
    
else:
   print("There is a",(prediction),"% that this image is of a robot.")
# Out:
# 1/1 [==============================] - 0s 14ms/step
# There is a [[0.99943167]] % that this image is of a robot.
